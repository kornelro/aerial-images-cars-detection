# %%
import cv2
import matplotlib.pyplot as plt

# %%
image = cv2.imread("../../data/raw/aerial-cars-dataset/DJI-00760-00001.jpg")

# %%
plt.imshow(image)
plt.show()

# %%
brightLAB = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

plt.imshow(brightLAB)
plt.show()

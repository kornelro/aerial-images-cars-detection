# %%
import pickle
import matplotlib.pyplot as plt
from src.features.processors import Blur, EqualHist
import numpy as numpy
import cv2

# %%
DATA_PATH = '../../data/processed/aerial-cars-dataset/svm/data_svm.pickle'

# %%
with open(DATA_PATH, 'rb') as f:
    data = pickle.load(f)

# %%
blur = Blur()
equal_hist = EqualHist()

# %%
car = data[0][0]
plt.imshow(car)
plt.show()
plt.imshow(blur.process(car))
plt.show()
plt.imshow(equal_hist.process(car))
plt.show()

# %%
car = data[5][0]
plt.imshow(car)
plt.show()
plt.imshow(blur.process(car))
plt.show()
plt.imshow(equal_hist.process(car))
plt.show()

# %%
car = data[9][0]
plt.imshow(car)
plt.show()
plt.imshow(blur.process(car))
plt.show()
plt.imshow(equal_hist.process(car))
plt.show()

# %%
car = data[13][0]
plt.imshow(car)
plt.show()
plt.imshow(blur.process(car))
plt.show()
plt.imshow(equal_hist.process(car))
plt.show()
